# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_MODEL_NAME"]="gpt-4o"

# %%
from crewai import Crew, Agent, Task

international_chef = Agent(
    role="Intenational Chef",
    goal="Create ethnic cuisine recipies that are easy to cook at home",
    backstory="""
    You are a famous chef that specializes in cuisine from countries all around the world.
    You know how to cook the most traditional dishes from all cultures but you also know how to adapt them for people to be able to cook them at home.
    """,
    verbose=True,
    allow_delegation=False,
)

healthy_chef = Agent(
    role="Healthy Chef",
    goal="Turn any recipe into a healthy vegetarian recipe that is easy to cook with home ingredients.",
    backstory="""
    You are a chef specialized in healthy cooking.
    You can take any recipe and change the ingredients to make it vegetarian friendly without loosing the escense of the dish and what makes it delicious.
    """,
    verbose=True,
    allow_delegation=False,
)

# %%
normal_recipe = Task(
    description="Come up with a {dish} that serves {people} people.",
    agent=international_chef,
    expected_output="Your answer MUST have three sections, the ingredients required with their quantities, the preparation instructions and serving suggestions",
    output_file="normal_recipe.md"
)

healthy_recipe = Task(
    description="Replace the ingredients of a recipe to make it vegetarian without making it less delicious, adjust if needed.",
    agent=healthy_chef,
    expected_output="Your answer MUST have four sections, the ingredients required with their quantities, the preparation instructions, serving suggestions and an explanation of the replaced ingredients",
    output_file="healthy_recipe.md"
)

# %%
crew = Crew(
    tasks=[
        normal_recipe,
        healthy_recipe,
    ],
    agents=[
        international_chef,
        healthy_chef,
    ],
    verbose=2,
)

result = crew.kickoff(
    inputs=dict(
        dish= "Greek dinner",
        people= "5",
    ),
)
# Out:
#  [DEBUG]: == Working Agent: Intenational Chef
#  [INFO]: == Starting Task: Come up with a Greek dinner that serves 5 people.
#
#
# I encountered an error while trying to use the tool. This was the error: 'NoneType' object has no attribute 'startswith'.
#  Tool Ask question to co-worker accepts these inputs: Ask question to co-worker(question: str, context: str, coworker: Optional[str] = None, **kwargs) - Ask a specific question to one of the following co-workers: [Healthy Chef]
# The input to this tool should be the co-worker, the question you have for them, and ALL necessary context to ask the question properly, they know nothing about the question, so share absolute everything you know, don't reference things but instead explain them.
#
#
#
# I encountered an error while trying to use the tool. This was the error: 'NoneType' object has no attribute 'startswith'.
#  Tool Ask question to co-worker accepts these inputs: Ask question to co-worker(question: str, context: str, coworker: Optional[str] = None, **kwargs) - Ask a specific question to one of the following co-workers: [Healthy Chef]
# The input to this tool should be the co-worker, the question you have for them, and ALL necessary context to ask the question properly, they know nothing about the question, so share absolute everything you know, don't reference things but instead explain them.
#
#  [DEBUG]: == [Intenational Chef] Task output: ### Greek Dinner Menu for 5 People
#
# #### Main Course: Moussaka
#
# **Ingredients:**
# - 2 large eggplants, sliced into 1/4-inch rounds
# - Salt (for sprinkling on eggplant)
# - 2 large potatoes, sliced into 1/4-inch rounds
# - 1 large onion, finely chopped
# - 2 cloves garlic, minced
# - 1 lb ground beef or lamb
# - 1 can (15 oz) crushed tomatoes
# - 2 tbsp tomato paste
# - 1/2 cup red wine (optional)
# - 1 tsp ground cinnamon
# - 1 tsp ground allspice
# - 1 bay leaf
# - 1/4 cup chopped fresh parsley
# - 1/4 cup grated Parmesan cheese
# - Olive oil (for frying)
# - Salt and pepper to taste
#
# **Béchamel Sauce:**
# - 4 tbsp butter
# - 4 tbsp all-purpose flour
# - 2 cups milk
# - 1/4 cup grated Parmesan cheese
# - 1/4 tsp ground nutmeg
# - Salt and pepper to taste
#
# **Preparation Instructions:**
# 1. Sprinkle the eggplant slices with salt and let them sit for 30 minutes to draw out excess moisture. Rinse and pat dry.
# 2. Preheat the oven to 375°F (190°C). Grease a large baking dish.
# 3. In a large skillet, heat some olive oil over medium heat. Fry the eggplant slices in batches until golden brown on both sides. Remove and drain on paper towels.
# 4. In the same skillet, add more olive oil if needed and fry the potato slices until golden brown. Remove and drain on paper towels.
# 5. In the same skillet, sauté the chopped onion and garlic until softened. Add the ground beef or lamb and cook until browned.
# 6. Stir in the crushed tomatoes, tomato paste, red wine (if using), cinnamon, allspice, bay leaf, parsley, salt, and pepper. Simmer for 20-25 minutes until the sauce thickens. Remove the bay leaf.
# 7. To make the béchamel sauce, melt the butter in a saucepan over medium heat. Stir in the flour and cook for 1-2 minutes. Gradually whisk in the milk and continue to cook until the sauce thickens. Stir in the Parmesan cheese, nutmeg, salt, and pepper.
# 8. Layer the potato slices on the bottom of the baking dish. Add a layer of eggplant slices on top.
# 9. Spread the meat sauce over the eggplant layer. Add another layer of eggplant slices.
# 10. Pour the béchamel sauce over the top layer of eggplant and spread evenly. Sprinkle with grated Parmesan cheese.
# 11. Bake in the preheated oven for 45-50 minutes until the top is golden brown. Allow to cool slightly before serving.
#
# #### Side Dish: Greek Salad
#
# **Ingredients:**
# - 4 large tomatoes, chopped
# - 1 cucumber, sliced
# - 1 green bell pepper, sliced
# - 1 red onion, thinly sliced
# - 1/2 cup Kalamata olives
# - 1/4 cup crumbled feta cheese
# - 1/4 cup extra-virgin olive oil
# - 2 tbsp red wine vinegar
# - 1 tsp dried oregano
# - Salt and pepper to taste
#
# **Preparation Instructions:**
# 1. In a large bowl, combine the tomatoes, cucumber, green bell pepper, red onion, and Kalamata olives.
# 2. In a small bowl, whisk together the olive oil, red wine vinegar, oregano, salt, and pepper.
# 3. Pour the dressing over the salad and toss to combine.
# 4. Sprinkle the crumbled feta cheese on top before serving.
#
# #### Dessert: Baklava
#
# **Ingredients:**
# - 1 package (16 oz) phyllo dough, thawed
# - 2 cups walnuts, finely chopped
# - 1 tsp ground cinnamon
# - 1 cup butter, melted
# - 1 cup water
# - 1 cup granulated sugar
# - 1/2 cup honey
# - 1 tsp vanilla extract
#
# **Preparation Instructions:**
# 1. Preheat the oven to 350°F (175°C). Grease a 9x13-inch baking dish.
# 2. In a bowl, combine the chopped walnuts and ground cinnamon.
# 3. Unroll the phyllo dough and cut it to fit the baking dish. Cover with a damp cloth to prevent drying out.
# 4. Place one sheet of phyllo dough in the baking dish and brush with melted butter. Repeat this process, layering 8 sheets of phyllo.
# 5. Sprinkle a thin layer of the walnut mixture over the phyllo.
# 6. Add 2 more sheets of phyllo, brushing each with butter. Sprinkle another layer of walnuts. Repeat this process until all the walnut mixture is used.
# 7. Finish with 8 layers of phyllo dough, brushing each with butter.
# 8. Using a sharp knife, cut the baklava into diamond or square shapes.
# 9. Bake in the preheated oven for 45-50 minutes until golden and crisp.
# 10. While the baklava is baking, combine the water, sugar, honey, and vanilla extract in a saucepan. Bring to a boil, then reduce the heat and simmer for 10 minutes.
# 11. Pour the hot syrup over the baked baklava and let it soak in. Allow the baklava to cool completely before serving.
#
# ### Serving Suggestions:
# - Serve the Moussaka warm with a slice of crusty bread.
# - The Greek Salad can be served on the side as a refreshing accompaniment.
# - Finish the meal with a sweet piece of Baklava and a cup of Greek coffee or tea.
#
# Enjoy your traditional Greek dinner!
#
#
#  [DEBUG]: == Working Agent: Healthy Chef
#  [INFO]: == Starting Task: Replace the ingredients of a recipe to make it vegetarian without making it less delicious, adjust if needed.
#
#
# I encountered an error while trying to use the tool. This was the error: 'NoneType' object has no attribute 'startswith'.
#  Tool Ask question to co-worker accepts these inputs: Ask question to co-worker(question: str, context: str, coworker: Optional[str] = None, **kwargs) - Ask a specific question to one of the following co-workers: [Intenational Chef]
# The input to this tool should be the co-worker, the question you have for them, and ALL necessary context to ask the question properly, they know nothing about the question, so share absolute everything you know, don't reference things but instead explain them.
#
#
#
# To turn a traditional Greek Moussaka into a vegetarian version while maintaining its rich and hearty flavor, the best alternative to replace the 1 lb of ground beef or lamb is to use a combination of lentils and mushrooms. This combination will provide a similar texture and depth of flavor. Here is how you can make the substitution:
#
# ### Ingredients:
# - 1 cup green or brown lentils, cooked
# - 8 oz mushrooms, finely chopped (portobello or cremini work well)
# - 1 large onion, finely chopped
# - 2 cloves garlic, minced
# - 1 can (14.5 oz) diced tomatoes
# - 2 tbsp tomato paste
# - 1/2 cup vegetable broth
# - 1 tsp ground cinnamon
# - 1/2 tsp ground allspice
# - 1/4 tsp ground nutmeg
# - 1/4 cup red wine (optional, but adds depth of flavor)
# - Salt and pepper to taste
# - 3 tbsp olive oil
#
# ### Instructions:
# 1. **Prepare Lentils**: Cook the lentils according to the package instructions until they are tender. Drain and set aside.
#
# 2. **Cook Mushrooms**: In a large skillet, heat 1 tbsp of olive oil over medium heat. Add the finely chopped mushrooms and cook until they release their moisture and become browned, about 8-10 minutes. Remove the mushrooms from the skillet and set aside.
#
# 3. **Sauté Aromatics**: In the same skillet, add the remaining olive oil and sauté the chopped onion until it becomes translucent, about 5 minutes. Add the minced garlic and cook for another minute.
#
# 4. **Combine Ingredients**: Add the cooked lentils, browned mushrooms, diced tomatoes, tomato paste, vegetable broth, red wine (if using), and spices (cinnamon, allspice, nutmeg) to the skillet. Stir to combine.
#
# 5. **Simmer**: Allow the mixture to simmer on low heat for about 20-25 minutes, stirring occasionally, until it thickens and the flavors meld together. Season with salt and pepper to taste.
#
# 6. **Assemble Moussaka**: Use this vegetarian mixture in place of the ground meat in your traditional Moussaka recipe. Layer it with the roasted eggplants and bechamel sauce as per usual.
#
# This substitution will ensure that your vegetarian Moussaka retains the rich and hearty flavors characteristic of the traditional dish. The lentils provide a meaty texture and protein, while the mushrooms add umami and depth.
#
# Enjoy your delicious vegetarian Moussaka!
#
#  [DEBUG]: == [Healthy Chef] Task output: ### Vegetarian Greek Dinner Menu for 5 People
#
# #### Main Course: Vegetarian Moussaka
#
# **Ingredients:**
# - 2 large eggplants, sliced into 1/4-inch rounds
# - Salt (for sprinkling on eggplant)
# - 2 large potatoes, sliced into 1/4-inch rounds
# - 1 large onion, finely chopped
# - 2 cloves garlic, minced
# - 1 cup green or brown lentils, cooked
# - 8 oz mushrooms, finely chopped (portobello or cremini)
# - 1 can (14.5 oz) diced tomatoes
# - 2 tbsp tomato paste
# - 1/2 cup vegetable broth
# - 1/4 cup red wine (optional)
# - 1 tsp ground cinnamon
# - 1/2 tsp ground allspice
# - 1/4 tsp ground nutmeg
# - 3 tbsp olive oil
# - 1 bay leaf
# - 1/4 cup chopped fresh parsley
# - 1/4 cup grated Parmesan cheese
# - Olive oil (for frying)
# - Salt and pepper to taste
#
# **Béchamel Sauce:**
# - 4 tbsp butter
# - 4 tbsp all-purpose flour
# - 2 cups milk
# - 1/4 cup grated Parmesan cheese
# - 1/4 tsp ground nutmeg
# - Salt and pepper to taste
#
# **Preparation Instructions:**
# 1. Sprinkle the eggplant slices with salt and let them sit for 30 minutes to draw out excess moisture. Rinse and pat dry.
# 2. Preheat the oven to 375°F (190°C). Grease a large baking dish.
# 3. In a large skillet, heat some olive oil over medium heat. Fry the eggplant slices in batches until golden brown on both sides. Remove and drain on paper towels.
# 4. In the same skillet, add more olive oil if needed and fry the potato slices until golden brown. Remove and drain on paper towels.
# 5. In the same skillet, heat 1 tbsp of olive oil over medium heat. Add the finely chopped mushrooms and cook until they release their moisture and become browned, about 8-10 minutes. Remove the mushrooms from the skillet and set aside.
# 6. In the same skillet, add the remaining 2 tbsp of olive oil and sauté the chopped onion until translucent, about 5 minutes. Add the minced garlic and cook for another minute.
# 7. Add the cooked lentils, browned mushrooms, diced tomatoes, tomato paste, vegetable broth, red wine (if using), cinnamon, allspice, nutmeg, bay leaf, parsley, salt, and pepper to the skillet. Stir to combine.
# 8. Allow the mixture to simmer on low heat for about 20-25 minutes, stirring occasionally, until it thickens and the flavors meld together. Remove the bay leaf.
# 9. To make the béchamel sauce, melt the butter in a saucepan over medium heat. Stir in the flour and cook for 1-2 minutes. Gradually whisk in the milk and continue to cook until the sauce thickens. Stir in the Parmesan cheese, nutmeg, salt, and pepper.
# 10. Layer the potato slices on the bottom of the baking dish. Add a layer of eggplant slices on top.
# 11. Spread the vegetarian filling over the eggplant layer. Add another layer of eggplant slices.
# 12. Pour the béchamel sauce over the top layer of eggplant and spread evenly. Sprinkle with grated Parmesan cheese.
# 13. Bake in the preheated oven for 45-50 minutes until the top is golden brown. Allow to cool slightly before serving.
#
# #### Side Dish: Greek Salad
#
# **Ingredients:**
# - 4 large tomatoes, chopped
# - 1 cucumber, sliced
# - 1 green bell pepper, sliced
# - 1 red onion, thinly sliced
# - 1/2 cup Kalamata olives
# - 1/4 cup crumbled feta cheese
# - 1/4 cup extra-virgin olive oil
# - 2 tbsp red wine vinegar
# - 1 tsp dried oregano
# - Salt and pepper to taste
#
# **Preparation Instructions:**
# 1. In a large bowl, combine the tomatoes, cucumber, green bell pepper, red onion, and Kalamata olives.
# 2. In a small bowl, whisk together the olive oil, red wine vinegar, oregano, salt, and pepper.
# 3. Pour the dressing over the salad and toss to combine.
# 4. Sprinkle the crumbled feta cheese on top before serving.
#
# #### Dessert: Baklava
#
# **Ingredients:**
# - 1 package (16 oz) phyllo dough, thawed
# - 2 cups walnuts, finely chopped
# - 1 tsp ground cinnamon
# - 1 cup butter, melted
# - 1 cup water
# - 1 cup granulated sugar
# - 1/2 cup honey
# - 1 tsp vanilla extract
#
# **Preparation Instructions:**
# 1. Preheat the oven to 350°F (175°C). Grease a 9x13-inch baking dish.
# 2. In a bowl, combine the chopped walnuts and ground cinnamon.
# 3. Unroll the phyllo dough and cut it to fit the baking dish. Cover with a damp cloth to prevent drying out.
# 4. Place one sheet of phyllo dough in the baking dish and brush with melted butter. Repeat this process, layering 8 sheets of phyllo.
# 5. Sprinkle a thin layer of the walnut mixture over the phyllo.
# 6. Add 2 more sheets of phyllo, brushing each with butter. Sprinkle another layer of walnuts. Repeat this process until all the walnut mixture is used.
# 7. Finish with 8 layers of phyllo dough, brushing each with butter.
# 8. Using a sharp knife, cut the baklava into diamond or square shapes.
# 9. Bake in the preheated oven for 45-50 minutes until golden and crisp.
# 10. While the baklava is baking, combine the water, sugar, honey, and vanilla extract in a saucepan. Bring to a boil, then reduce the heat and simmer for 10 minutes.
# 11. Pour the hot syrup over the baked baklava and let it soak in. Allow the baklava to cool completely before serving.
#
# ### Serving Suggestions:
# - Serve the Moussaka warm with a slice of crusty bread.
# - The Greek Salad can be served on the side as a refreshing accompaniment.
# - Finish the meal with a sweet piece of Baklava and a cup of Greek coffee or tea.
#
# ### Explanation of Replaced Ingredients:
# - Ground beef or lamb is replaced with a combination of lentils and mushrooms to maintain a similar texture and rich flavor.
# - The lentils provide protein and a meaty texture, while the mushrooms add umami and depth to the dish.
#
# Enjoy your traditional Greek vegetarian dinner!
